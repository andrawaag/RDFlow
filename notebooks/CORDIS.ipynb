# %% [markdown]
# RDFLow
# ========================
# An implementation of the RDFlow pipeline for the documentation and visualization of constantly evolving RDF datasets.
#
# # Data

# %%
# %run ../extract_schema.py ../schemas/CORDIS ../data/CORDIS/Project.ttl
# Out:
# sheXer version: 2.6.5.1
# 19/09/2025 13:17:59 -- Starting instance tracker...
# 19/09/2025 13:19:10 -- Instance tracker finished. 182673 instances located
# 19/09/2025 13:19:10 -- Starting class profiler...
# 19/09/2025 13:19:10 -- Instance counts completed. Annotating instance features...
# 19/09/2025 13:20:12 -- Instance features annotated. Number of relevant triples computed: 2644039. Building shape profiles...
# 19/09/2025 13:20:14 -- Draft shape profiles built. Cleaning shape profiles...
# 19/09/2025 13:20:14 -- Shape profiles done. Working with 3 shapes.
# 19/09/2025 13:20:14 -- Detecting example features for each shape...
# 19/09/2025 13:20:15 -- Mimimal IRIs detected...
# 19/09/2025 13:20:15 -- Starting shape extraction...
# 19/09/2025 13:20:15 -- Shape drafts built. Sorting constraints...
# 19/09/2025 13:20:15 -- Constraints sorted. Adjusting cardinalities...
# 19/09/2025 13:20:15 -- Cardinalities adjusted. Cleaning empty shapes if needed...
# ...

# %%
# !docker run --rm -it  -v /Users/andra/project/RDFlow:/config  dbcls/rdf-config:latest  rdf-config --config /config/schemas/CORDIS --schema >/Users/andra/project/RDFlow/schemas/CORDIS/rdf-config-schema.svg
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Python(74901) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
